# %%
# %sql

USE CATALOG cat_clintrail_dev;
USE SCHEMA  schema_clintrail_bronze;


-- ---------------------------------------------------------------------------
-- DM  Demographics                                    source PK: USUBJID
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.dm (
    STUDYID       STRING,
    DOMAIN        STRING,
    USUBJID       STRING,
    SUBJID        STRING,
    SITEID        STRING,
    COUNTRY       STRING,
    RFICDTC       DATE,
    RFSTDTC       DATE,
    RFENDTC       DATE,
    AGE           INT,
    AGEU          STRING,
    SEX           STRING,
    RACE          STRING,
    ETHNIC        STRING,
    ARM           STRING,
    ARMCD         STRING,
    ACTARM        STRING,
    ACTARMCD      STRING,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/dm'
COMMENT 'Bronze: raw DM (Demographics). Append-only history. Delta feed.';


-- ---------------------------------------------------------------------------
-- SV  Subject Visits                          source PK: USUBJID, VISITNUM
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.sv (
    STUDYID       STRING,
    DOMAIN        STRING,
    USUBJID       STRING,
    VISITNUM      DECIMAL(5,1),
    VISIT         STRING,
    SVSTDTC       DATE,
    SVENDTC       DATE,
    PROTOCOLDEV   STRING,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/sv'
COMMENT 'Bronze: raw SV (Subject Visits). Append-only history. Delta feed.';


-- ---------------------------------------------------------------------------
-- VS  Vital Signs                                source PK: USUBJID, VSSEQ
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.vs (
    STUDYID       STRING,
    DOMAIN        STRING,
    USUBJID       STRING,
    VSSEQ         INT,
    VSTESTCD      STRING,
    VSTEST        STRING,
    VSORRES       DECIMAL(12,3),
    VSORRESU      STRING,
    VISITNUM      DECIMAL(5,1),
    VISIT         STRING,
    VSDTC         DATE,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/vs'
COMMENT 'Bronze: raw VS (Vital Signs). Append-only history. Delta feed.';


-- ---------------------------------------------------------------------------
-- LB  Laboratory                                 source PK: USUBJID, LBSEQ
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.lb (
    STUDYID       STRING,
    DOMAIN        STRING,
    USUBJID       STRING,
    LBSEQ         INT,
    LBTESTCD      STRING,
    LBTEST        STRING,
    LBCAT         STRING,
    LBORRES       DECIMAL(12,3),
    LBORRESU      STRING,
    LBORNRLO      DECIMAL(12,3),
    LBORNRHI      DECIMAL(12,3),
    LBNRIND       STRING,
    VISITNUM      DECIMAL(5,1),
    VISIT         STRING,
    LBDTC         DATE,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/lb'
COMMENT 'Bronze: raw LB (Laboratory). Append-only history. Delta feed.';


-- ---------------------------------------------------------------------------
-- EG  ECG                                        source PK: USUBJID, EGSEQ
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.eg (
    STUDYID       STRING,
    DOMAIN        STRING,
    USUBJID       STRING,
    EGSEQ         INT,
    EGTESTCD      STRING,
    EGTEST        STRING,
    EGORRES       DECIMAL(12,3),
    EGORRESU      STRING,
    VISITNUM      DECIMAL(5,1),
    VISIT         STRING,
    EGDTC         DATE,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/eg'
COMMENT 'Bronze: raw EG (ECG). Append-only history. Delta feed.';


-- ---------------------------------------------------------------------------
-- EC  Exposure as Collected                      source PK: USUBJID, ECSEQ
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.ec (
    STUDYID       STRING,
    DOMAIN        STRING,
    USUBJID       STRING,
    ECSEQ         INT,
    ECTRT         STRING,
    ECDOSE        DECIMAL(10,2),
    ECDOSU        STRING,
    ECROUTE       STRING,
    ECSTDTC       DATE,
    ECENDTC       DATE,
    VISITNUM      DECIMAL(5,1),
    VISIT         STRING,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/ec'
COMMENT 'Bronze: raw EC (Exposure as Collected). Append-only history. Delta feed.';


-- ---------------------------------------------------------------------------
-- CM  Concomitant Medications                    source PK: USUBJID, CMSEQ
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.cm (
    STUDYID       STRING,
    DOMAIN        STRING,
    USUBJID       STRING,
    CMSEQ         INT,
    CMTRT         STRING,
    CMDECOD       STRING,
    CMDOSE        DECIMAL(10,2),
    CMDOSU        STRING,
    CMROUTE       STRING,
    CMSTDTC       DATE,
    CMENDTC       DATE,
    CMINDC        STRING,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/cm'
COMMENT 'Bronze: raw CM (Concomitant Medications). Append-only history. Delta feed.';


-- ---------------------------------------------------------------------------
-- DS  Disposition                                source PK: USUBJID, DSSEQ
-- Snapshot feed: each landing file holds the FULL table, not a delta.
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.ds (
    STUDYID       STRING,
    DOMAIN        STRING,
    USUBJID       STRING,
    DSSEQ         INT,
    DSTERM        STRING,
    DSDECOD       STRING,
    DSCAT         STRING,
    DSSTDTC       DATE,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/ds'
COMMENT 'Bronze: raw DS (Disposition). Append-only history of daily FULL snapshots.';


-- ---------------------------------------------------------------------------
-- TA  Trial Arms (reference)             source PK: STUDYID, ARMCD, TAETORD
-- Snapshot feed.
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.ta (
    STUDYID       STRING,
    DOMAIN        STRING,
    ARMCD         STRING,
    ARM           STRING,
    TAETORD       INT,
    ETCD          STRING,
    ELEMENT       STRING,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/ta'
COMMENT 'Bronze: raw TA (Trial Arms). Append-only history of daily FULL snapshots.';


-- ---------------------------------------------------------------------------
-- TS  Trial Summary (reference)             source PK: STUDYID, TSPARMCD
-- Snapshot feed.
-- ---------------------------------------------------------------------------
CREATE TABLE IF NOT EXISTS cat_clintrail_dev.schema_clintrail_bronze.ts (
    STUDYID       STRING,
    DOMAIN        STRING,
    TSPARMCD      STRING,
    TSPARM        STRING,
    TSVAL         STRING,
    MODIFIED_TS   TIMESTAMP,
    bronze_ingest_date  DATE
)
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/ts'
COMMENT 'Bronze: raw TS (Trial Summary). Append-only history of daily FULL snapshots.';


-- ============================================================================
-- Verify
-- ============================================================================
SHOW TABLES IN cat_clintrail_dev.schema_clintrail_bronze;          -- expect 10

-- Confirm each is EXTERNAL (not MANAGED) and CDF is on.
--   Type must read EXTERNAL. If it says MANAGED, the LOCATION was ignored and your
--   data is sitting in the catalog's _managed folder instead of your container.
DESCRIBE TABLE EXTENDED cat_clintrail_dev.schema_clintrail_bronze.dm;

# %%
# %sql SHOW EXTERNAL LOCATIONS;

# %%
# %sql
CREATE TABLE test_dm
USING DELTA
LOCATION 'abfss://bronze@stclintrialdev009.dfs.core.windows.net/test';

# %%
# %sql
DESCRIBE EXTERNAL LOCATION `ext-loc-clintrail-bronze`;

# %%
# %sql
DESCRIBE SCHEMA EXTENDED cat_clintrail_dev.schema_clintrail_bronze;

# %%
# %sql
SHOW TABLES IN cat_clintrail_dev.schema_clintrail_bronze;

# %%
# %sql
SHOW TABLES IN cat_clintrail_dev.schema_clintrail_bronze;

# %%
# %sql
DROP SCHEMA cat_clintrail_dev.schema_clintrail_bronze CASCADE;

# %%
# %sql
CREATE SCHEMA cat_clintrail_dev.schema_clintrail_bronze;
